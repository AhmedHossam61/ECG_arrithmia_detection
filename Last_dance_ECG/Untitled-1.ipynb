    541, 547, 542, 535, 547, 553, 547, 546, 559, 564, 556, 560, 572, 578, 572, 582, 594, 595, 586, 597, 608, 601, 589,
    595, 592, 576, 560, 566, 559, 544, 537, 545, 545, 537, 540, 547, 545, 534, 541, 549, 545, 535, 543, 549, 545, 536,
    548, 554, 546, 542, 553, 555, 544, 542, 554, 555, 542, 543, 553, 552, 541, 545, 553, 552, 540, 547, 554, 547, 537,
    550, 556, 554, 552, 562, 570, 567, 574, 594, 598, 585, 581, 585, 576, 555, 553, 554, 547, 536, 546, 552, 546, 537,
    546, 549, 541, 523, 500, 470, 474, 570, 748, 907, 1021, 1024, 775, 548, 436, 422, 445, 457, 470, 499, 513, 508,
    512, 522, 522, 513, 521, 532, 528, 519, 530, 537, 535, 528, 541, 545, 540, 535, 550, 554, 546, 545, 556, 560, 552,
    556, 569, 571, 565, 574, 586, 586, 581, 594, 601, 597, 590, 600, 602, 590, 576, 577, 570, 552, 542, 546, 543, 530,
    530, 537, 536, 525, 533, 540, 536, 526, 536, 543, 538, 532, 542, 545, 537, 532, 543, 546, 535, 534, 545, 545, 534,
    535, 542, 542, 531, 536, 542, 537, 528, 536, 542, 535, 528, 537, 541, 532, 526, 540, 541, 528, 528, 542, 546, 538,
    545, 558, 560, 559, 577, 585, 579, 562, 566, 559, 546, 533, 536, 535, 528, 522, 533, 535, 524, 524, 535, 533, 502,
    469, 451, 484, 594, 772, 934, 1024, 992, 744, 533, 422, 394, 429, 456, 463, 481, 499, 505, 494, 499, 508, 507, 498,
    508, 516, 513, 506, 517, 523, 519, 514, 525, 528, 521, 518, 526, 530, 522, 525, 537, 541, 532, 541, 553, 555, 549,
    559, 568, 567, 561, 576, 582, 577, 570, 579, 574, 556, 543, 545, 537, 521, 518, 524, 521, 507, 509, 516, 513, 505,
    514, 522, 517, 509, 522, 526, 518, 512, 523, 526, 519, 519, 530, 529, 519, 522, 529, 528, 517, 523, 529, 525, 514,
    525, 530, 522, 513, 523, 528, 522, 517, 528, 532, 522, 522, 533, 534, 523, 525, 535, 534, 523, 531, 541, 543, 535,
    546, 553, 555, 558, 576, 580, 567, 556, 559, 554, 536, 528, 534, 534, 522, 525, 535, 535]



def preprocess_ecg_batch_for_prediction(raw_signals, sample_rate=125, output_length=187):
    """
    Preprocess multiple raw ECG signals for prediction.
    """
    # Convert to numpy array if not already
    raw_signals = np.array(raw_signals)

    # Check if input is 1D, and reshape to 2D if needed
    if raw_signals.ndim == 1:
        raw_signals = np.array([raw_signals])

    n_samples = len(raw_signals)
    processed_signals = np.zeros((n_samples, output_length, 1))

    for i, raw_signal in enumerate(raw_signals):
        # Skip filtering for very short signals or if filtering fails
        try:
            # Apply bandpass filter
            nyquist = 0.5 * sample_rate
            low = 0.5 / nyquist
            high = 40.0 / nyquist
            b, a = butter(2, [low, high], btype='band')

            # Check if signal is long enough for filtfilt (needs length > 3 * (max(len(a), len(b)) - 1))
            min_length = 3 * (max(len(a), len(b)) - 1)
            if len(raw_signal) > min_length:
                filtered_signal = filtfilt(b, a, raw_signal)
            else:
                filtered_signal = raw_signal  # Use raw signal if too short
        except Exception as e:
            print(f"Filtering failed for signal {i}: {e}")
            filtered_signal = raw_signal

        # Normalize the signal
        signal_mean = np.mean(filtered_signal)
        signal_std = np.std(filtered_signal)
        if signal_std > 1e-10:  # Avoid division by zero
            normalized_signal = (filtered_signal - signal_mean) / signal_std
        else:
            normalized_signal = filtered_signal - signal_mean

        # Rest of your code remains the same...
        # Find R peaks (the prominent peaks in ECG)
        peaks, _ = find_peaks(normalized_signal, height=0.5, distance=int(sample_rate * 0.5))

        # Initialize the processed signal with zeros
        processed_signal = np.zeros(output_length)

        if len(peaks) >= 2:
            # Get the first two R peaks
            r1, r2 = peaks[0], peaks[1]

            # Calculate beat length
            beat_length = r2 - r1

            # Calculate half beat before first R peak
            half_beat = beat_length // 2
            start_idx = max(0, r1 - half_beat)

            # Extract segment (half beat + full beat)
            end_idx = min(len(normalized_signal), start_idx + beat_length + half_beat)
            segment = normalized_signal[start_idx:end_idx]

            # Place segment at the beginning of the output array
            if len(segment) <= output_length:
                processed_signal[:len(segment)] = segment
            else:
                processed_signal = segment[:output_length]

        elif len(peaks) == 1:
            # If only one peak is found, use an estimated beat length
            r1 = peaks[0]
            estimated_beat_length = int(sample_rate * 0.7)  # ~0.7 seconds, typical for heart beat

            # Calculate half beat before R peak
            half_beat = estimated_beat_length // 2
            start_idx = max(0, r1 - half_beat)

            # Extract segment
            end_idx = min(len(normalized_signal), start_idx + estimated_beat_length + half_beat)
            segment = normalized_signal[start_idx:end_idx]

            # Place segment at the beginning of the output array
            if len(segment) <= output_length:
                processed_signal[:len(segment)] = segment
            else:
                processed_signal = segment[:output_length]

        else:
            # If no peaks found, use a segment from the beginning
            segment = normalized_signal[:min(output_length, len(normalized_signal))]
            processed_signal[:len(segment)] = segment

        # Add to batch
        processed_signals[i, :, 0] = processed_signal

    return processed_signals

def predict_arrhythmia_batch(raw_signals, model, class_names=None):
    """
    Process multiple raw ECG signals and predict the arrhythmia class for each.

    Parameters:
    raw_signals (array): Array of raw ECG signals
    model: Loaded Keras CNN model
    class_names (list): Names of the arrhythmia classes

    Returns:
    predicted_classes (array): Predicted class indices
    class_names (array): Names of the predicted classes
    confidences (array): Confidence scores for the predictions
    """
    if class_names is None:
        class_names = ['Normal', 'Supraventricular', 'Ventricular', 'Fusion', 'Unknown']

    # Preprocess the signals
    processed_signals = preprocess_ecg_batch_for_prediction(raw_signals)

    # Make predictions
    predictions = model.predict(processed_signals)
    predicted_classes = np.argmax(predictions, axis=1)
    confidences = np.max(predictions, axis=1)

    # Get class names
    predicted_class_names = [class_names[idx] for idx in predicted_classes]

    return predicted_classes, predicted_class_names, confidences



import numpy as np
from tensorflow.keras.models import load_model
from scipy.signal import find_peaks, butter, filtfilt


from tensorflow.keras.models import load_model
# model = load_model('project_model.keras')
model = load_model('claude2_ecg_detection_model.keras')

# Use the X variable that contains your ECG data
# First, we need to format it appropriately since it looks like it has 3 signals concatenated
signal_length = 187  # Based on the plot and your comment
signals = []

# Split the X array into 3 separate signals (assuming they are contiguous)
for i in range(0, len(X), signal_length):
    if i + signal_length <= len(X):
        signals.append(X[i:i+signal_length])
    else:
        # Handle the last segment if it's not complete
        last_signal = X[i:]
        # Pad with zeros if needed
        if len(last_signal) < signal_length:
            last_signal = np.pad(last_signal, (0, signal_length - len(last_signal)))
        signals.append(last_signal)

# Convert to numpy array
raw_ecg_data = np.array(signals)

# Now we can proceed with prediction
class_indices, class_names, confidences = predict_arrhythmia_batch(raw_ecg_data, model)

# Display results for each signal
for i, (class_idx, class_name, confidence) in enumerate(zip(class_indices, class_names, confidences)):
    print(f"Signal {i+1}: Predicted {class_name} with {confidence*100:.2f}% confidence")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\site-packages\keras\src\saving\serialization_lib.py:800, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     799 try:
# --> 800     mod = importlib.import_module(module)
#     801 except ModuleNotFoundError:
#
# File c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'keras.src.models.functional'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 204
#     202 from tensorflow.keras.models import load_model
#     203 # model = load_model('project_model.keras')
# --> 204 model = load_model('claude2_ecg_detection_model.keras')
#     206 # Use the X variable that contains your ECG data
#     207 # First, we need to format it appropriately since it looks like it has 3 signals concatenated
#     208 signal_length = 187  # Based on the plot and your comment
#
# File c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\site-packages\keras\src\saving\saving_api.py:254, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     249     if kwargs:
#     250         raise ValueError(
#     251             "The following argument(s) are not supported "
#     252             f"with the native Keras format: {list(kwargs.keys())}"
#     253         )
# --> 254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
#     262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\site-packages\keras\src\saving\saving_lib.py:281, in load_model(filepath, custom_objects, compile, safe_mode)
#     278             asset_store.close()
#     280 except Exception as e:
# --> 281     raise e
#     282 else:
#     283     return model
#
# File c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\site-packages\keras\src\saving\saving_lib.py:246, in load_model(filepath, custom_objects, compile, safe_mode)
#     244 # Construct the model from the configuration file in the archive.
#     245 with ObjectSharingScope():
# --> 246     model = deserialize_keras_object(
#     247         config_dict, custom_objects, safe_mode=safe_mode
#     248     )
#     250 all_filenames = zf.namelist()
#     251 if _VARS_FNAME + ".h5" in all_filenames:
#
# File c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\site-packages\keras\src\saving\serialization_lib.py:705, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     702     if obj is not None:
#     703         return obj
# --> 705 cls = _retrieve_class_or_fn(
#     706     class_name,
#     707     registered_name,
#     708     module,
#     709     obj_type="class",
#     710     full_config=config,
#     711     custom_objects=custom_objects,
#     712 )
#     714 if isinstance(cls, types.FunctionType):
#     715     return cls
#
# File c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\site-packages\keras\src\saving\serialization_lib.py:802, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     800     mod = importlib.import_module(module)
#     801 except ModuleNotFoundError:
# --> 802     raise TypeError(
#     803         f"Could not deserialize {obj_type} '{name}' because "
#     804         f"its parent module {module} cannot be imported. "
#     805         f"Full object config: {full_config}"
#     806     )
#     807 obj = vars(mod).get(name, None)
#     809 if obj is None:
#     810     # Special case for keras.metrics.metrics
#
# TypeError: Could not deserialize class 'Functional' because its parent module keras.src.models.functional cannot be imported. Full object config: {'module': 'keras.src.models.functional', 'class_name': 'Functional', 'config': {'name': 'functional', 'trainable': True, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': [None, 187, 1], 'dtype': 'float32', 'sparse': False, 'name': 'input_layer'}, 'registered_name': None, 'name': 'input_layer', 'inbound_nodes': []}, {'module': 'keras.layers', 'class_name': 'Conv1D', 'config': {'name': 'conv1d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 64, 'kernel_size': [7], 'strides': [1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 187, 1]}, 'name': 'conv1d', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 187, 1], 'dtype': 'float32', 'keras_history': ['input_layer', 0, 0]}}], 'kwargs': {}}]}, {'module': 'keras.layers', 'class_name': 'BatchNormalization', 'config': {'name': 'batch_normalization', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 137205863037968}, 'axis': -1, 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'gamma_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'moving_mean_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'moving_variance_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None, 'synchronized': False}, 'registered_name': None, 'build_config': {'input_shape': [None, 187, 64]}, 'name': 'batch_normalization', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 187, 64], 'dtype': 'float32', 'keras_history': ['conv1d', 0, 0]}}], 'kwargs': {'mask': None}}]}, {'module': 'keras.layers', 'class_name': 'Activation', 'config': {'name': 'activation', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 137205863037968}, 'activation': 'relu'}, 'registered_name': None, 'name': 'activation', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 187, 64], 'dtype': 'float32', 'keras_history': ['batch_normalization', 0, 0]}}], 'kwargs': {}}]}, {'module': 'keras.layers', 'class_name': 'MaxPooling1D', 'config': {'name': 'max_pooling1d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 137205863037968}, 'pool_size': [2], 'padding': 'valid', 'strides': [2], 'data_format': 'channels_last'}, 'registered_name': None, 'name': 'max_pooling1d', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 187, 64], 'dtype': 'float32', 'keras_history': ['activation', 0, 0]}}], 'kwargs': {}}]}, {'module': 'keras.layers', 'class_name': 'Conv1D', 'config': {'name': 'conv1d_1', 't ...

# %% [markdown]
# # Claude with GUI

# %% [markdown]
# # Working with Mock sick patient

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import threading
import time
from scipy.signal import find_peaks, butter, filtfilt
from collections import deque

# Your ECG preprocessing functions
def preprocess_ecg_batch_for_prediction(raw_signals, sample_rate=125, output_length=187):
    """
    Preprocess multiple raw ECG signals for prediction.
    """
    # Convert to numpy array if not already
    raw_signals = np.array(raw_signals)

    # Check if input is 1D, and reshape to 2D if needed
    if raw_signals.ndim == 1:
        raw_signals = np.array([raw_signals])

    n_samples = len(raw_signals)
    processed_signals = np.zeros((n_samples, output_length, 1))

    for i, raw_signal in enumerate(raw_signals):
        # Skip filtering for very short signals or if filtering fails
        try:
            # Apply bandpass filter
            nyquist = 0.5 * sample_rate
            low = 0.5 / nyquist
            high = 40.0 / nyquist
            b, a = butter(2, [low, high], btype='band')

            # Check if signal is long enough for filtfilt (needs length > 3 * (max(len(a), len(b)) - 1))
            min_length = 3 * (max(len(a), len(b)) - 1)
            if len(raw_signal) > min_length:
                filtered_signal = filtfilt(b, a, raw_signal)
            else:
                filtered_signal = raw_signal  # Use raw signal if too short
        except Exception as e:
            print(f"Filtering failed for signal {i}: {e}")
            filtered_signal = raw_signal

        # Normalize the signal
        signal_mean = np.mean(filtered_signal)
        signal_std = np.std(filtered_signal)
        if signal_std > 1e-10:  # Avoid division by zero
            normalized_signal = (filtered_signal - signal_mean) / signal_std
        else:
            normalized_signal = filtered_signal - signal_mean

        # Find R peaks (the prominent peaks in ECG)
        peaks, _ = find_peaks(normalized_signal, height=0.5, distance=int(sample_rate * 0.5))

        # Initialize the processed signal with zeros
        processed_signal = np.zeros(output_length)

        if len(peaks) >= 2:
            # Get the first two R peaks
            r1, r2 = peaks[0], peaks[1]

            # Calculate beat length
            beat_length = r2 - r1

            # Calculate half beat before first R peak
            half_beat = beat_length // 2
            start_idx = max(0, r1 - half_beat)

            # Extract segment (half beat + full beat)
            end_idx = min(len(normalized_signal), start_idx + beat_length + half_beat)
            segment = normalized_signal[start_idx:end_idx]

            # Place segment at the beginning of the output array
            if len(segment) <= output_length:
                processed_signal[:len(segment)] = segment
            else:
                processed_signal = segment[:output_length]

        elif len(peaks) == 1:
            # If only one peak is found, use an estimated beat length
            r1 = peaks[0]
            estimated_beat_length = int(sample_rate * 0.7)  # ~0.7 seconds, typical for heart beat

            # Calculate half beat before R peak
            half_beat = estimated_beat_length // 2
            start_idx = max(0, r1 - half_beat)

            # Extract segment
            end_idx = min(len(normalized_signal), start_idx + estimated_beat_length + half_beat)
            segment = normalized_signal[start_idx:end_idx]

            # Place segment at the beginning of the output array
            if len(segment) <= output_length:
                processed_signal[:len(segment)] = segment
            else:
                processed_signal = segment[:output_length]

        else:
            # If no peaks found, use a segment from the beginning
            segment = normalized_signal[:min(output_length, len(normalized_signal))]
            processed_signal[:len(segment)] = segment

        # Add to batch
        processed_signals[i, :, 0] = processed_signal

    return processed_signals

def predict_arrhythmia_batch(raw_signals, model, class_names=None):
    """
    Process multiple raw ECG signals and predict the arrhythmia class for each.
    """
    if class_names is None:
        class_names = ['Normal', 'Supraventricular', 'Ventricular', 'Fusion', 'Unknown']

    # Preprocess the signals
    processed_signals = preprocess_ecg_batch_for_prediction(raw_signals)

    # Make predictions
    predictions = model.predict(processed_signals, verbose=0)
    predicted_classes = np.argmax(predictions, axis=1)
    confidences = np.max(predictions, axis=1)

    # Get class names
    predicted_class_names = [class_names[idx] for idx in predicted_classes]

    return predicted_classes, predicted_class_names, confidences

# Mock model class for testing
class MockModel:
    def __init__(self):
        self.class_names = ['Normal', 'Supraventricular', 'Ventricular', 'Fusion', 'Unknown']
        
    def predict(self, x, verbose=0):
        """Return mock predictions with realistic patterns"""
        n_samples = x.shape[0] if hasattr(x, 'shape') else len(x)
        predictions = []
        
        for i in range(n_samples):
            # Create more realistic predictions (mostly normal with some abnormal)
            rand = np.random.random()
            if rand < 0.6:  # 60% normal
                pred = [0.8, 0.1, 0.05, 0.03, 0.02]
            elif rand < 0.8:  # 20% supraventricular
                pred = [0.2, 0.7, 0.05, 0.03, 0.02]
            elif rand < 0.9:  # 10% ventricular
                pred = [0.1, 0.1, 0.75, 0.03, 0.02]
            elif rand < 0.95:  # 5% fusion
                pred = [0.1, 0.1, 0.1, 0.68, 0.02]
            else:  # 5% unknown
                pred = [0.1, 0.1, 0.1, 0.02, 0.68]
            
            predictions.append(pred)
        
        return np.array(predictions)

class ECGRealtimeGUI:
    def __init__(self, root, ecg_data, model):
        self.root = root
        self.ecg_data = np.array(ecg_data)
        self.model = model
        self.samples_per_beat = 187
        self.duration_per_beat = 0.5  # seconds
        
        # Animation control
        self.is_playing = False
        self.is_paused = False
        self.current_index = 0
        self.speed_multiplier = 1.0
        self.thread = None
        
        # Data for plotting
        self.window_size = 500
        self.y_data = deque(maxlen=self.window_size)
        self.x_data = deque(maxlen=self.window_size)
        
        # Predictions
        self.beats = self.split_into_beats()
        self.predictions = self.calculate_all_predictions()
        self.current_prediction = "Ready"
        self.current_confidence = 0.0
        
        self.setup_gui()
        
    def split_into_beats(self):
        """Split ECG data into beats for prediction"""
        beats = []
        for i in range(0, len(self.ecg_data), self.samples_per_beat):
            if i + self.samples_per_beat <= len(self.ecg_data):
                beats.append(self.ecg_data[i:i+self.samples_per_beat])
        return beats
    
    def calculate_all_predictions(self):
        """Pre-calculate all predictions"""
        predictions = []
        for i, beat in enumerate(self.beats):
            try:
                _, class_names, confidences = predict_arrhythmia_batch([beat], self.model)
                predictions.append({
                    'class': class_names[0],
                    'confidence': confidences[0]
                })
            except Exception as e:
                predictions.append({
                    'class': 'Error',
                    'confidence': 0.0
                })
        return predictions
    
    def setup_gui(self):
        """Setup the GUI components"""
        self.root.title("ECG Real-Time Monitor with Arrhythmia Detection")
        self.root.geometry("1200x800")
        
        # Create main frame
        main_frame = ttk.Frame(self.root)
        main_frame.pack(fill=tk.BOTH, expand=True, padx=10, pady=10)
        
        # Control panel
        control_frame = ttk.LabelFrame(main_frame, text="Controls", padding="10")
        control_frame.pack(fill=tk.X, pady=(0, 10))
        
        # Buttons
        button_frame = ttk.Frame(control_frame)
        button_frame.pack(side=tk.LEFT)
        
        self.play_button = ttk.Button(button_frame, text="▶ Play", command=self.play)
        self.play_button.pack(side=tk.LEFT, padx=(0, 5))
        
        self.pause_button = ttk.Button(button_frame, text="⏸ Pause", command=self.pause)
        self.pause_button.pack(side=tk.LEFT, padx=(0, 5))
        
        self.stop_button = ttk.Button(button_frame, text="⏹ Stop", command=self.stop)
        self.stop_button.pack(side=tk.LEFT, padx=(0, 5))
        
        self.reset_button = ttk.Button(button_frame, text="🔄 Reset", command=self.reset)
        self.reset_button.pack(side=tk.LEFT, padx=(0, 5))
        
        # Speed control
        speed_frame = ttk.Frame(control_frame)
        speed_frame.pack(side=tk.RIGHT)
        
        ttk.Label(speed_frame, text="Speed:").pack(side=tk.LEFT)
        self.speed_var = tk.DoubleVar(value=1.0)
        self.speed_scale = ttk.Scale(speed_frame, from_=0.1, to=5.0, 
                                   variable=self.speed_var, orient=tk.HORIZONTAL,
                                   length=200, command=self.update_speed)
        self.speed_scale.pack(side=tk.LEFT, padx=(5, 5))
        self.speed_label = ttk.Label(speed_frame, text="1.0x")
        self.speed_label.pack(side=tk.LEFT)
        
        # Progress bar
        progress_frame = ttk.Frame(main_frame)
        progress_frame.pack(fill=tk.X, pady=(0, 10))
        
        ttk.Label(progress_frame, text="Progress:").pack(side=tk.LEFT)
        self.progress_var = tk.DoubleVar()
        self.progress_bar = ttk.Progressbar(progress_frame, variable=self.progress_var, 
                                          maximum=len(self.ecg_data))
        self.progress_bar.pack(side=tk.LEFT, fill=tk.X, expand=True, padx=(5, 5))
        self.progress_label = ttk.Label(progress_frame, text="0/0")
        self.progress_label.pack(side=tk.LEFT)
        
        # Create matplotlib figure
        plot_frame = ttk.LabelFrame(main_frame, text="ECG Signal", padding="5")
        plot_frame.pack(fill=tk.BOTH, expand=True)
        
        self.fig = Figure(figsize=(12, 6), dpi=100)
        self.ax1 = self.fig.add_subplot(211)
        self.ax2 = self.fig.add_subplot(212)
        
        # ECG plot
        self.line, = self.ax1.plot([], [], 'b-', linewidth=2)
        self.current_marker, = self.ax1.plot([], [], 'ro', markersize=8)
        self.ax1.set_ylabel('Amplitude')
        self.ax1.set_title('ECG Waveform (Real-time)')
        self.ax1.grid(True, alpha=0.3)
        
        # Set initial limits
        data_min, data_max = min(self.ecg_data), max(self.ecg_data)
        data_range = data_max - data_min
        self.ax1.set_ylim(data_min - 0.1*data_range, data_max + 0.1*data_range)
        self.ax1.set_xlim(0, self.window_size)
        
        # Prediction display
        self.ax2.axis('off')
        self.prediction_text = self.ax2.text(0.3, 0.7, 'Classification: Ready', 
                                           fontsize=16, ha='left', va='center',
                                           bbox=dict(boxstyle="round,pad=0.3", facecolor="lightblue"))
        self.confidence_text = self.ax2.text(0.3, 0.4, 'Confidence: 0.0%', 
                                           fontsize=14, ha='left', va='center')
        self.beat_text = self.ax2.text(0.3, 0.1, 'Beat: 0/0', 
                                     fontsize=12, ha='left', va='center')
        
        # Embed plot in tkinter
        self.canvas = FigureCanvasTkAgg(self.fig, plot_frame)
        self.canvas.draw()
        self.canvas.get_tk_widget().pack(fill=tk.BOTH, expand=True)
        
        # Status bar
        self.status_var = tk.StringVar(value="Ready to start ECG monitoring")
        status_bar = ttk.Label(main_frame, textvariable=self.status_var, relief=tk.SUNKEN)
        status_bar.pack(fill=tk.X, pady=(5, 0))
        
    def get_color_for_prediction(self, prediction):
        """Get color based on prediction"""
        color_map = {
            'Normal': 'lightgreen',
            'Supraventricular': 'yellow',
            'Ventricular': 'orange',
            'Fusion': 'lightcoral',
            'Unknown': 'lightgray',
            'Error': 'red',
            'Ready': 'lightblue'
        }
        return color_map.get(prediction, 'lightblue')
    
    def update_speed(self, value):
        """Update animation speed"""
        self.speed_multiplier = float(value)
        self.speed_label.config(text=f"{self.speed_multiplier:.1f}x")
    
    def play(self):
        """Start/resume the ECG animation"""
        if not self.is_playing:
            self.is_playing = True
            self.is_paused = False
            self.status_var.set("Playing ECG monitoring...")
            self.thread = threading.Thread(target=self.animation_loop, daemon=True)
            self.thread.start()
        elif self.is_paused:
            self.is_paused = False
            self.status_var.set("Resumed ECG monitoring...")
    
    def pause(self):
        """Pause the animation"""
        if self.is_playing:
            self.is_paused = True
            self.status_var.set("Paused")
    
    def stop(self):
        """Stop the animation"""
        self.is_playing = False
        self.is_paused = False
        self.status_var.set("Stopped")
    
    def reset(self):
        """Reset to beginning"""
        self.stop()
        time.sleep(0.1)  # Wait for thread to stop
        self.current_index = 0
        self.y_data.clear()
        self.x_data.clear()
        self.current_prediction = "Ready"
        self.current_confidence = 0.0
        self.progress_var.set(0)
        self.progress_label.config(text=f"0/{len(self.ecg_data)}")
        self.update_plot()
        self.status_var.set("Reset to beginning")
    
    def animation_loop(self):
        """Main animation loop running in separate thread"""
        while self.is_playing and self.current_index < len(self.ecg_data):
            if not self.is_paused:
                # Add current sample
                current_value = self.ecg_data[self.current_index]
                self.y_data.append(current_value)
                self.x_data.append(self.current_index)
                
                # Update prediction at beat boundaries
                if self.current_index % self.samples_per_beat == 0 and self.current_index > 0:
                    beat_num = self.current_index // self.samples_per_beat
                    if beat_num <= len(self.predictions):
                        if beat_num - 1 < len(self.predictions):
                            pred = self.predictions[beat_num - 1]
                            self.current_prediction = pred['class']
                            self.current_confidence = pred['confidence']
                
                # Update GUI (must be done in main thread)
                self.root.after(0, self.update_plot)
                self.root.after(0, self.update_progress)
                
                self.current_index += 1
                
                # Calculate sleep time based on speed
                sleep_time = (self.duration_per_beat / self.samples_per_beat) / self.speed_multiplier
                time.sleep(max(0.001, sleep_time))  # Minimum 1ms
            else:
                time.sleep(0.1)  # Check pause state every 100ms
        
        # Animation finished
        if self.current_index >= len(self.ecg_data):
            self.root.after(0, lambda: self.status_var.set("ECG monitoring completed"))
            self.is_playing = False
    
    def update_plot(self):
        """Update the plot (called from main thread)"""
        if len(self.y_data) > 0:
            # Update ECG line
            self.line.set_data(list(self.x_data), list(self.y_data))
            
            # Update current position marker
            if len(self.x_data) > 0:
                self.current_marker.set_data([list(self.x_data)[-1]], [list(self.y_data)[-1]])
            
            # Update x-axis limits to follow data
            if len(self.x_data) >= self.window_size:
                self.ax1.set_xlim(list(self.x_data)[0], list(self.x_data)[-1])
            
            # Update prediction display
            self.prediction_text.set_text(f"Classification: {self.current_prediction}")
            self.prediction_text.set_bbox(dict(boxstyle="round,pad=0.3", 
                                             facecolor=self.get_color_for_prediction(self.current_prediction)))
            
            self.confidence_text.set_text(f"Confidence: {self.current_confidence*100:.1f}%")
            
            current_beat = (self.current_index // self.samples_per_beat) + 1
            self.beat_text.set_text(f"Beat: {current_beat}/{len(self.beats)}")
            
            self.canvas.draw_idle()
    
    def update_progress(self):
        """Update progress bar"""
        self.progress_var.set(self.current_index)
        self.progress_label.config(text=f"{self.current_index}/{len(self.ecg_data)}")

def main():
    # Your X data (this would be imported from your notebook)
    X = [
        596, 589, 595, 601, 596, 578, 576, 572, 560, 543, 547, 546, 535, 525, 534, 535,
        528, 526, 536, 536, 526, 526, 535, 536, 525, 532, 542, 541, 529, 537, 545, 541,
        532, 542, 546, 538, 531, 542, 546, 535, 532, 541, 542, 532, 533, 543, 546, 540,
        546, 558, 559, 554, 571, 585, 585, 573, 580, 576, 558, 542, 543, 543, 533, 528,
        550, 556, 554, 552, 562, 570, 567, 574, 594, 598, 585, 581, 585, 576, 555, 553, 554, 547, 536, 546, 552, 546, 537,
        546, 549, 541, 523, 500, 470, 474, 570, 748, 907, 1021, 1024, 775, 548, 436, 422, 445, 457, 470, 499, 513, 508,
        512, 522, 522, 513, 521, 532, 528, 519, 530, 537, 535, 528, 541, 545, 540, 535, 550, 554, 546, 545, 556, 560, 552,
        556, 569, 571, 565, 574, 586, 586, 581, 594, 601, 597, 590, 600, 602, 590, 576, 577, 570, 552, 542, 546, 543, 530,
        530, 537, 536, 525, 533, 540, 536, 526, 536, 543, 538, 532, 542, 545, 537, 532, 543, 546, 535, 534, 545, 545, 534,
        535, 542, 542, 531, 536, 542, 537, 528, 536, 542, 535, 528, 537, 541, 532, 526, 540, 541, 528, 528, 542, 546, 538,
        545, 558, 560, 559, 577, 585, 579, 562, 566, 559, 546, 533, 536, 535, 528, 522, 533, 535, 524, 524, 535, 533, 502,
        469, 451, 484, 594, 772, 934, 1024, 992, 744, 533, 422, 394, 429, 456, 463, 481, 499, 505, 494, 499, 508, 507, 498,
        508, 516, 513, 506, 517, 523, 519, 514, 525, 528, 521, 518, 526, 530, 522, 525, 537, 541, 532, 541, 553, 555, 549,
        559, 568, 567, 561, 576, 582, 577, 570, 579, 574, 556, 543, 545, 537, 521, 518, 524, 521, 507, 509, 516, 513, 505,
        514, 522, 517, 509, 522, 526, 518, 512, 523, 526, 519, 519, 530, 529, 519, 522, 529, 528, 517, 523, 529, 525, 514,
        525, 530, 522, 513, 523, 528, 522, 517, 528, 532, 522, 522, 533, 534, 523, 525, 535, 534, 523, 531, 541, 543, 535,
        546, 553, 555, 558, 576, 580, 567, 556, 559, 554, 536, 528, 534, 534, 522, 525, 535, 535
    ]
    
    print("Starting ECG GUI Application...")
    print(f"ECG data length: {len(X)}")
    print(f"ECG data range: {min(X)} to {max(X)}")
    
    # Try to load your model
    model = None
    try:
        # Uncomment the next lines when you have your model file
        from tensorflow.keras.models import load_model
        model = load_model('claude2_ecg_detection_model.keras')
        pass
    except:
        pass
    
    if model is None:
        print("Using mock model for demonstration.")
        print("To use your real model, uncomment the model loading lines in main().")
        model = MockModel()
    
    # Create GUI
    root = tk.Tk()
    app = ECGRealtimeGUI(root, X, model)
    
    # Start the GUI
    try:
        root.mainloop()
    except KeyboardInterrupt:
        print("Application terminated by user")

if __name__ == "__main__":
    main()
# Out:
# Starting ECG GUI Application...
# ECG data length: 1354
# ECG data range: 387 to 1024
# Using mock model for demonstration.
# To use your real model, uncomment the model loading lines in main().
# Exception in thread Thread-17 (animation_loop):
# Traceback (most recent call last):
#   File "c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ahmedhoss\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ahmedhoss\AppData\Local\Temp\ipykernel_21004\922492331.py", line 382, in animation_loop
#   File "c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\tkinter\__init__.py", line 872, in after
#     name = self._register(callit)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\tkinter\__init__.py", line 1603, in _register
#     self.tk.createcommand(name, f)
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Variable.__del__ at 0x000002076A2559E0>
# Traceback (most recent call last):
#   File "c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\tkinter\__init__.py", line 410, in __del__
#     if self._tk.getboolean(self._tk.call("info", "exists", self._name)):
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Variable.__del__ at 0x000002076A2559E0>
# Traceback (most recent call last):
#   File "c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\tkinter\__init__.py", line 410, in __del__
#     if self._tk.getboolean(self._tk.call("info", "exists", self._name)):
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Variable.__del__ at 0x000002076A2559E0>
# Traceback (most recent call last):
#   File "c:\Users\ahmedhoss\anaconda3\envs\Py_11\Lib\tkinter\__init__.py", line 410, in __del__
#     if self._tk.getboolean(self._tk.call("info", "exists", self._name)):
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: main thread is not in main loop

# %% [markdown]
# # Working with Mock Normal patient
#
# ### After You run it, Choose 1 or 2 to continue

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import threading
import time
from scipy.signal import find_peaks, butter, filtfilt
from collections import deque

# Your ECG preprocessing functions
def preprocess_ecg_batch_for_prediction(raw_signals, sample_rate=125, output_length=187):
    """
    Preprocess multiple raw ECG signals for prediction.
    """
    # Convert to numpy array if not already
    raw_signals = np.array(raw_signals)

    # Check if input is 1D, and reshape to 2D if needed
    if raw_signals.ndim == 1:
        raw_signals = np.array([raw_signals])

    n_samples = len(raw_signals)
    processed_signals = np.zeros((n_samples, output_length, 1))

    for i, raw_signal in enumerate(raw_signals):
        # Skip filtering for very short signals or if filtering fails
        try:
            # Apply bandpass filter
            nyquist = 0.5 * sample_rate
            low = 0.5 / nyquist
            high = 40.0 / nyquist
            b, a = butter(2, [low, high], btype='band')

            # Check if signal is long enough for filtfilt (needs length > 3 * (max(len(a), len(b)) - 1))
            min_length = 3 * (max(len(a), len(b)) - 1)
            if len(raw_signal) > min_length:
                filtered_signal = filtfilt(b, a, raw_signal)
            else:
                filtered_signal = raw_signal  # Use raw signal if too short
        except Exception as e:
            print(f"Filtering failed for signal {i}: {e}")
            filtered_signal = raw_signal

        # Normalize the signal
        signal_mean = np.mean(filtered_signal)
        signal_std = np.std(filtered_signal)
        if signal_std > 1e-10:  # Avoid division by zero
            normalized_signal = (filtered_signal - signal_mean) / signal_std
        else:
            normalized_signal = filtered_signal - signal_mean

        # Find R peaks (the prominent peaks in ECG)
        peaks, _ = find_peaks(normalized_signal, height=0.5, distance=int(sample_rate * 0.5))

        # Initialize the processed signal with zeros
        processed_signal = np.zeros(output_length)

        if len(peaks) >= 2:
            # Get the first two R peaks
            r1, r2 = peaks[0], peaks[1]

            # Calculate beat length
            beat_length = r2 - r1

            # Calculate half beat before first R peak
            half_beat = beat_length // 2
            start_idx = max(0, r1 - half_beat)

            # Extract segment (half beat + full beat)
            end_idx = min(len(normalized_signal), start_idx + beat_length + half_beat)
            segment = normalized_signal[start_idx:end_idx]

            # Place segment at the beginning of the output array
            if len(segment) <= output_length:
                processed_signal[:len(segment)] = segment
            else:
                processed_signal = segment[:output_length]

        elif len(peaks) == 1:
            # If only one peak is found, use an estimated beat length
            r1 = peaks[0]
            estimated_beat_length = int(sample_rate * 0.7)  # ~0.7 seconds, typical for heart beat

            # Calculate half beat before R peak
            half_beat = estimated_beat_length // 2
            start_idx = max(0, r1 - half_beat)

            # Extract segment
            end_idx = min(len(normalized_signal), start_idx + estimated_beat_length + half_beat)
            segment = normalized_signal[start_idx:end_idx]

            # Place segment at the beginning of the output array
            if len(segment) <= output_length:
                processed_signal[:len(segment)] = segment
            else:
                processed_signal = segment[:output_length]

        else:
            # If no peaks found, use a segment from the beginning
            segment = normalized_signal[:min(output_length, len(normalized_signal))]
            processed_signal[:len(segment)] = segment

        # Add to batch
        processed_signals[i, :, 0] = processed_signal

    return processed_signals

def predict_arrhythmia_batch(raw_signals, model, class_names=None):
    """
    Process multiple raw ECG signals and predict the arrhythmia class for each.
    """
    if class_names is None:
        class_names = ['Normal', 'Supraventricular', 'Ventricular', 'Fusion', 'Unknown']

    # Preprocess the signals
    processed_signals = preprocess_ecg_batch_for_prediction(raw_signals)

    # Make predictions
    predictions = model.predict(processed_signals, verbose=0)
    predicted_classes = np.argmax(predictions, axis=1)
    confidences = np.max(predictions, axis=1)

    # Get class names
    predicted_class_names = [class_names[idx] for idx in predicted_classes]

    return predicted_classes, predicted_class_names, confidences

# Mock model classes for testing
class MockModel:
    def __init__(self):
        self.class_names = ['Normal', 'Supraventricular', 'Ventricular', 'Fusion', 'Unknown']
        
    def predict(self, x, verbose=0):
        """Return mock predictions with realistic patterns"""
        n_samples = x.shape[0] if hasattr(x, 'shape') else len(x)
        predictions = []
        
        for i in range(n_samples):
            # Create more realistic predictions (mostly normal with some abnormal)
            rand = np.random.random()
            if rand < 0.6:  # 60% normal
                pred = [0.8, 0.1, 0.05, 0.03, 0.02]
            elif rand < 0.8:  # 20% supraventricular
                pred = [0.2, 0.7, 0.05, 0.03, 0.02]
            elif rand < 0.9:  # 10% ventricular
                pred = [0.1, 0.1, 0.75, 0.03, 0.02]
            elif rand < 0.95:  # 5% fusion
                pred = [0.1, 0.1, 0.1, 0.68, 0.02]
            else:  # 5% unknown
                pred = [0.1, 0.1, 0.1, 0.02, 0.68]
            
            predictions.append(pred)
        
        return np.array(predictions)

class MockModelAllNormal:
    def __init__(self):
        self.class_names = ['Normal', 'Supraventricular', 'Ventricular', 'Fusion', 'Unknown']
        
    def predict(self, x, verbose=0):
        """Return mock predictions - all classified as Normal"""
        n_samples = x.shape[0] if hasattr(x, 'shape') else len(x)
        predictions = []
        
        for i in range(n_samples):
            # All predictions are "Normal" with high confidence
            # Small random variation in confidence (90-95%)
            confidence = 0.90 + np.random.random() * 0.05  # 90-95%
            remaining = 1.0 - confidence
            
            # Distribute remaining probability among other classes
            pred = [confidence, remaining*0.4, remaining*0.3, remaining*0.2, remaining*0.1]
            predictions.append(pred)
        
        return np.array(predictions)

class ECGRealtimeGUI:
    def __init__(self, root, ecg_data, model):
        self.root = root
        self.ecg_data = np.array(ecg_data)
        self.model = model
        self.samples_per_beat = 187
        self.duration_per_beat = 0.5  # seconds
        
        # Animation control
        self.is_playing = False
        self.is_paused = False
        self.current_index = 0
        self.speed_multiplier = 1.0
        self.thread = None
        
        # Data for plotting
        self.window_size = 500
        self.y_data = deque(maxlen=self.window_size)
        self.x_data = deque(maxlen=self.window_size)
        
        # Predictions
        self.beats = self.split_into_beats()
        self.predictions = self.calculate_all_predictions()
        self.current_prediction = "Ready"
        self.current_confidence = 0.0
        
        self.setup_gui()
        
    def split_into_beats(self):
        """Split ECG data into beats for prediction"""
        beats = []
        for i in range(0, len(self.ecg_data), self.samples_per_beat):
            if i + self.samples_per_beat <= len(self.ecg_data):
                beats.append(self.ecg_data[i:i+self.samples_per_beat])
        return beats
    
    def calculate_all_predictions(self):
        """Pre-calculate all predictions"""
        predictions = []
        for i, beat in enumerate(self.beats):
            try:
                _, class_names, confidences = predict_arrhythmia_batch([beat], self.model)
                predictions.append({
                    'class': class_names[0],
                    'confidence': confidences[0]
                })
            except Exception as e:
                predictions.append({
                    'class': 'Error',
                    'confidence': 0.0
                })
        return predictions
    
    def setup_gui(self):
        """Setup the GUI components"""
        self.root.title("ECG Real-Time Monitor with Arrhythmia Detection")
        self.root.geometry("1200x800")
        
        # Create main frame
        main_frame = ttk.Frame(self.root)
        main_frame.pack(fill=tk.BOTH, expand=True, padx=10, pady=10)
        
        # Control panel
        control_frame = ttk.LabelFrame(main_frame, text="Controls", padding="10")
        control_frame.pack(fill=tk.X, pady=(0, 10))
        
        # Buttons
        button_frame = ttk.Frame(control_frame)
        button_frame.pack(side=tk.LEFT)
        
        self.play_button = ttk.Button(button_frame, text="▶ Play", command=self.play)
        self.play_button.pack(side=tk.LEFT, padx=(0, 5))
        
        self.pause_button = ttk.Button(button_frame, text="⏸ Pause", command=self.pause)
        self.pause_button.pack(side=tk.LEFT, padx=(0, 5))
        
        self.stop_button = ttk.Button(button_frame, text="⏹ Stop", command=self.stop)
        self.stop_button.pack(side=tk.LEFT, padx=(0, 5))
        
        self.reset_button = ttk.Button(button_frame, text="🔄 Reset", command=self.reset)
        self.reset_button.pack(side=tk.LEFT, padx=(0, 5))
        
        # Speed control
        speed_frame = ttk.Frame(control_frame)
        speed_frame.pack(side=tk.RIGHT)
        
        ttk.Label(speed_frame, text="Speed:").pack(side=tk.LEFT)
        self.speed_var = tk.DoubleVar(value=1.0)
        self.speed_scale = ttk.Scale(speed_frame, from_=0.1, to=5.0, 
                                   variable=self.speed_var, orient=tk.HORIZONTAL,
                                   length=200, command=self.update_speed)
        self.speed_scale.pack(side=tk.LEFT, padx=(5, 5))
        self.speed_label = ttk.Label(speed_frame, text="1.0x")
        self.speed_label.pack(side=tk.LEFT)
        
        # Progress bar
        progress_frame = ttk.Frame(main_frame)
        progress_frame.pack(fill=tk.X, pady=(0, 10))
        
        ttk.Label(progress_frame, text="Progress:").pack(side=tk.LEFT)
        self.progress_var = tk.DoubleVar()
        self.progress_bar = ttk.Progressbar(progress_frame, variable=self.progress_var, 
                                          maximum=len(self.ecg_data))
        self.progress_bar.pack(side=tk.LEFT, fill=tk.X, expand=True, padx=(5, 5))
        self.progress_label = ttk.Label(progress_frame, text="0/0")
        self.progress_label.pack(side=tk.LEFT)
        
        # Create matplotlib figure
        plot_frame = ttk.LabelFrame(main_frame, text="ECG Signal", padding="5")
        plot_frame.pack(fill=tk.BOTH, expand=True)
        
        self.fig = Figure(figsize=(12, 6), dpi=100)
        self.ax1 = self.fig.add_subplot(211)
        self.ax2 = self.fig.add_subplot(212)
        
        # ECG plot
        self.line, = self.ax1.plot([], [], 'b-', linewidth=2)
        self.current_marker, = self.ax1.plot([], [], 'ro', markersize=8)
        self.ax1.set_ylabel('Amplitude')
        self.ax1.set_title('ECG Waveform (Real-time)')
        self.ax1.grid(True, alpha=0.3)
        
        # Set initial limits
        data_min, data_max = min(self.ecg_data), max(self.ecg_data)
        data_range = data_max - data_min
        self.ax1.set_ylim(data_min - 0.1*data_range, data_max + 0.1*data_range)
        self.ax1.set_xlim(0, self.window_size)
        
        # Prediction display
        self.ax2.axis('off')
        self.prediction_text = self.ax2.text(0.3, 0.7, 'Classification: Ready', 
                                           fontsize=16, ha='left', va='center',
                                           bbox=dict(boxstyle="round,pad=0.3", facecolor="lightblue"))
        self.confidence_text = self.ax2.text(0.3, 0.4, 'Confidence: 0.0%', 
                                           fontsize=14, ha='left', va='center')
        self.beat_text = self.ax2.text(0.3, 0.1, 'Beat: 0/0', 
                                     fontsize=12, ha='left', va='center')
        
        # Embed plot in tkinter
        self.canvas = FigureCanvasTkAgg(self.fig, plot_frame)
        self.canvas.draw()
        self.canvas.get_tk_widget().pack(fill=tk.BOTH, expand=True)
        
        # Status bar
        self.status_var = tk.StringVar(value="Ready to start ECG monitoring")
        status_bar = ttk.Label(main_frame, textvariable=self.status_var, relief=tk.SUNKEN)
        status_bar.pack(fill=tk.X, pady=(5, 0))
        
    def get_color_for_prediction(self, prediction):
        """Get color based on prediction"""
        color_map = {
            'Normal': 'lightgreen',
            'Supraventricular': 'yellow',
            'Ventricular': 'orange',
            'Fusion': 'lightcoral',
            'Unknown': 'lightgray',
            'Error': 'red',
            'Ready': 'lightblue'
        }
        return color_map.get(prediction, 'lightblue')
    
    def update_speed(self, value):
        """Update animation speed"""
        self.speed_multiplier = float(value)
        self.speed_label.config(text=f"{self.speed_multiplier:.1f}x")
    
    def play(self):
        """Start/resume the ECG animation"""
        if not self.is_playing:
            self.is_playing = True
            self.is_paused = False
            self.status_var.set("Playing ECG monitoring...")
            self.thread = threading.Thread(target=self.animation_loop, daemon=True)
            self.thread.start()
        elif self.is_paused:
            self.is_paused = False
            self.status_var.set("Resumed ECG monitoring...")
    
    def pause(self):
        """Pause the animation"""
        if self.is_playing:
            self.is_paused = True
            self.status_var.set("Paused")
    
    def stop(self):
        """Stop the animation"""
        self.is_playing = False
        self.is_paused = False
        self.status_var.set("Stopped")
    
    def reset(self):
        """Reset to beginning"""
        self.stop()
        time.sleep(0.1)  # Wait for thread to stop
        self.current_index = 0
        self.y_data.clear()
        self.x_data.clear()
        self.current_prediction = "Ready"
        self.current_confidence = 0.0
        self.progress_var.set(0)
        self.progress_label.config(text=f"0/{len(self.ecg_data)}")
        self.update_plot()
        self.status_var.set("Reset to beginning")
    
    def animation_loop(self):
        """Main animation loop running in separate thread"""
        while self.is_playing and self.current_index < len(self.ecg_data):
            if not self.is_paused:
                # Add current sample
                current_value = self.ecg_data[self.current_index]
                self.y_data.append(current_value)
                self.x_data.append(self.current_index)
                
                # Update prediction at beat boundaries
                if self.current_index % self.samples_per_beat == 0 and self.current_index > 0:
                    beat_num = self.current_index // self.samples_per_beat
                    if beat_num <= len(self.predictions):
                        if beat_num - 1 < len(self.predictions):
                            pred = self.predictions[beat_num - 1]
                            self.current_prediction = pred['class']
                            self.current_confidence = pred['confidence']
                
                # Update GUI (must be done in main thread)
                self.root.after(0, self.update_plot)
                self.root.after(0, self.update_progress)
                
                self.current_index += 1
                
                # Calculate sleep time based on speed
                sleep_time = (self.duration_per_beat / self.samples_per_beat) / self.speed_multiplier
                time.sleep(max(0.001, sleep_time))  # Minimum 1ms
            else:
                time.sleep(0.1)  # Check pause state every 100ms
        
        # Animation finished
        if self.current_index >= len(self.ecg_data):
            self.root.after(0, lambda: self.status_var.set("ECG monitoring completed"))
            self.is_playing = False
    
    def update_plot(self):
        """Update the plot (called from main thread)"""
        if len(self.y_data) > 0:
            # Update ECG line
            self.line.set_data(list(self.x_data), list(self.y_data))
            
            # Update current position marker
            if len(self.x_data) > 0:
                self.current_marker.set_data([list(self.x_data)[-1]], [list(self.y_data)[-1]])
            
            # Update x-axis limits to follow data
            if len(self.x_data) >= self.window_size:
                self.ax1.set_xlim(list(self.x_data)[0], list(self.x_data)[-1])
            
            # Update prediction display
            self.prediction_text.set_text(f"Classification: {self.current_prediction}")
            self.prediction_text.set_bbox(dict(boxstyle="round,pad=0.3", 
                                             facecolor=self.get_color_for_prediction(self.current_prediction)))
            
            self.confidence_text.set_text(f"Confidence: {self.current_confidence*100:.1f}%")
            
            current_beat = (self.current_index // self.samples_per_beat) + 1
            self.beat_text.set_text(f"Beat: {current_beat}/{len(self.beats)}")
            
            self.canvas.draw_idle()
    
    def update_progress(self):
        """Update progress bar"""
        self.progress_var.set(self.current_index)
        self.progress_label.config(text=f"{self.current_index}/{len(self.ecg_data)}")

def main():
    # Your X data (this would be imported from your notebook)
    X = [
        596, 589, 595, 601, 596, 578, 576, 572, 560, 543, 547, 546, 535, 525, 534, 535,
        528, 526, 536, 536, 526, 526, 535, 536, 525, 532, 542, 541, 529, 537, 545, 541,
        532, 542, 546, 538, 531, 542, 546, 535, 532, 541, 542, 532, 533, 543, 546, 540,
        546, 558, 559, 554, 571, 585, 585, 573, 580, 576, 558, 542, 543, 543, 533, 528,
        540, 541, 530, 532, 541, 540, 526, 520, 493, 457, 459, 558, 730, 876, 974, 1006,
        546, 549, 541, 523, 500, 470, 474, 570, 748, 907, 1021, 1024, 775, 548, 436, 422, 445, 457, 470, 499, 513, 508,
        512, 522, 522, 513, 521, 532, 528, 519, 530, 537, 535, 528, 541, 545, 540, 535, 550, 554, 546, 545, 556, 560, 552,
        556, 569, 571, 565, 574, 586, 586, 581, 594, 601, 597, 590, 600, 602, 590, 576, 577, 570, 552, 542, 546, 543, 530,
        530, 537, 536, 525, 533, 540, 536, 526, 536, 543, 538, 532, 542, 545, 537, 532, 543, 546, 535, 534, 545, 545, 534,
        535, 542, 542, 531, 536, 542, 537, 528, 536, 542, 535, 528, 537, 541, 532, 526, 540, 541, 528, 528, 542, 546, 538,
        545, 558, 560, 559, 577, 585, 579, 562, 566, 559, 546, 533, 536, 535, 528, 522, 533, 535, 524, 524, 535, 533, 502,
        469, 451, 484, 594, 772, 934, 1024, 992, 744, 533, 422, 394, 429, 456, 463, 481, 499, 505, 494, 499, 508, 507, 498,
        508, 516, 513, 506, 517, 523, 519, 514, 525, 528, 521, 518, 526, 530, 522, 525, 537, 541, 532, 541, 553, 555, 549,
        559, 568, 567, 561, 576, 582, 577, 570, 579, 574, 556, 543, 545, 537, 521, 518, 524, 521, 507, 509, 516, 513, 505,
        514, 522, 517, 509, 522, 526, 518, 512, 523, 526, 519, 519, 530, 529, 519, 522, 529, 528, 517, 523, 529, 525, 514,
        525, 530, 522, 513, 523, 528, 522, 517, 528, 532, 522, 522, 533, 534, 523, 525, 535, 534, 523, 531, 541, 543, 535,
        546, 553, 555, 558, 576, 580, 567, 556, 559, 554, 536, 528, 534, 534, 522, 525, 535, 535
    ]
    
    print("Starting ECG GUI Application...")
    print(f"ECG data length: {len(X)}")
    print(f"ECG data range: {min(X)} to {max(X)}")
    
    # Try to load your model
    model = None
    try:
        # Uncomment the next lines when you have your model file
        # from tensorflow.keras.models import load_model
        # model = load_model('claude2_ecg_detection_model.keras')
        pass
    except:
        pass
    
    if model is None:
        print("\nChoose a mock model for demonstration:")
        print("1. Mixed predictions (Normal, Supraventricular, Ventricular, etc.)")
        print("2. All Normal predictions (all beats classified as Normal)")
        
        while True:
            try:
                choice = input("\nEnter your choice (1 or 2): ").strip()
                if choice == "1":
                    model = MockModel()
                    print("Using mixed predictions mock model.")
                    break
                elif choice == "2":
                    model = MockModelAllNormal()
                    print("Using all-normal predictions mock model.")
                    break
                else:
                    print("Please enter 1 or 2.")
            except KeyboardInterrupt:
                print("\nApplication terminated by user.")
                return
            except:
                print("Please enter 1 or 2.")
        
        print("To use your real model, uncomment the model loading lines in main().")
    
    # Create GUI
    root = tk.Tk()
    app = ECGRealtimeGUI(root, X, model)
    
    # Start the GUI
    try:
        root.mainloop()
    except KeyboardInterrupt:
        print("Application terminated by user")

if __name__ == "__main__":
    main()
# Out:
# Starting ECG GUI Application...
# ECG data length: 1354
# ECG data range: 387 to 1024
#
# Choose a mock model for demonstration:
# 1. Mixed predictions (Normal, Supraventricular, Ventricular, etc.)
# 2. All Normal predictions (all beats classified as Normal)
# Using all-normal predictions mock model.
# To use your real model, uncomment the model loading lines in main().
